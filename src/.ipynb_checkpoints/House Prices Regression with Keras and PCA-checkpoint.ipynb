# %% [markdown]
# # House Prices Regression

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Import Libraries

# %%
#%%bash
#pip install seaborn

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

import keras

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import ThresholdedReLU
from keras import metrics
from sklearn.decomposition import PCA
from sklearn import preprocessing
from scipy import stats
from scipy.stats import norm, skew

# %% [markdown]
# ### Setup Environment

# %%
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

# %% [markdown]
# ### Import Data

# %%
train = pd.read_csv('../input/train.csv')
test_x = pd.read_csv('../input/test.csv')

print('Train set shape: ', train.shape)
print('Test set shape: ', test_x.shape)
# Out:
# Train set shape:  (1460, 81)
# Test set shape:  (1459, 80)

# %% [markdown]
# ### Split Data

# %% [markdown]
# #### Specify target name

# %%
train_y_name = 'SalePrice'

# %% [markdown]
# #### Split target from data

# %%
train_y = train[train_y_name]
train_x = train.drop([train_y_name], axis=1)

# %% [markdown]
# #### Combine all  x data

# %%
all_x = pd.concat([train_x, test_x])

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Helper methods

# %% [markdown]
# #### Method to plot a simple data relation

# %%
def scatter(x, y, label_x, label_y):
    plt.scatter(x=x, y=y)
    plt.title(label_x + ' vs '  + label_y)
    plt.ylabel(label_y)
    plt.xlabel(label_x)
    plt.show()

# %% [markdown]
# #### Method to plot multiple columns

# %%
def scatter_all(df, y):
    for x in list(df):
        scatter(df[x], y)

# %% [markdown]
# #### Method to plot Correlation

# %%
def plot_correlation(df, target_col, k):
    data = df.dropna()
    cols = data.corr().nlargest(k, target_col)[target_col].index
    cm = np.corrcoef(data[cols].values.T)
    sns.set(font_scale=1.25)
    sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=list(cols), xticklabels=list(cols))
    plt.show()

# %% [markdown]
# ### Target

# %%
sns.distplot(train_y, fit=norm)
# Out:
# /Users/florianherborn/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# For better predictions we transfrom target to match the normal  distribution

# %%
train_y = np.log1p(train_y)
sns.distplot(train_y, fit=norm)

# %% [markdown]
# ### Categorical

# %% [markdown]
# #### Extract categorical values

# %%
categorical = all_x.select_dtypes(include=['object'])
categorical
# Out:
#      MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
# 5          RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 6          RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 7          RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 8          RM   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 9          RL   Pave   NaN      Reg         Lvl    AllPub    Corner       Gtl
# 10         RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# ...

# %% [markdown]
# #### Extract numerical

# %%
numerical = all_x.select_dtypes(exclude=['object'])
numerical
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# 5        6          50         85.0    14115            5            5
# 6        7          20         75.0    10084            8            5
# 7        8          60          NaN    10382            7            6
# 8        9          50         51.0     6120            7            5
# 9       10         190         50.0     7420            5            6
# 10      11          20         70.0    11200            5            5
# 11      12          60         85.0    11924            9            5
# ...

# %% [markdown]
# #### Check columns with  missing values in percent

# %%
cols_with_missing = all_x.isna().sum()
cols_with_missing = cols_with_missing[missing_sum > 0].sort_values(ascending=False)
cols_with_missing = 100 * cols_with_missing / all_x.shape[0]
cols_with_missing
# Out:
# PoolQC          99.657417
# MiscFeature     96.402878
# Alley           93.216855
# Fence           80.438506
# FireplaceQu     48.646797
# LotFrontage     16.649538
# GarageFinish     5.447071
# GarageYrBlt      5.447071
# GarageQual       5.447071
# GarageCond       5.447071
# GarageType       5.378554
# BsmtExposure     2.809181
# BsmtCond         2.809181
# BsmtQual         2.774923
# BsmtFinType2     2.740665
# BsmtFinType1     2.706406
# MasVnrType       0.822199
# MasVnrArea       0.787941
# MSZoning         0.137033
# BsmtFullBath     0.068517
# BsmtHalfBath     0.068517
# Utilities        0.068517
# Functional       0.068517
# Exterior2nd      0.034258
# Exterior1st      0.034258
# SaleType         0.034258
# BsmtFinSF1       0.034258
# BsmtFinSF2       0.034258
# BsmtUnfSF        0.034258
# Electrical       0.034258
# KitchenQual      0.034258
# GarageCars       0.034258
# GarageArea       0.034258
# TotalBsmtSF      0.034258
# dtype: float64

# %% [markdown]
# #### Fill missing

# %%
all_x_wo_missing = all_x

# %% [markdown]
# ##### PoolQC
# PoolQC: Pool quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        NA	No Pool
#
# Replace with NO for No Pool to use as new class

# %%
all_x_wo_missing['PoolQC'] = all_x['PoolQC'].fillna('NO')

# %% [markdown]
# ##### MiscFeature
# MiscFeature: Miscellaneous feature not covered in other categories
#
#        Elev	Elevator
#        Gar2	2nd Garage (if not described in garage section)
#        Othr	Other
#        Shed	Shed (over 100 SF)
#        TenC	Tennis Court
#        NA	None
#
# Replace with NO for No Feature to use as new class

# %%
all_x_wo_missing['MiscFeature'] = all_x['MiscFeature'].fillna('NO')

# %% [markdown]
# ##### Alley
# Alley: Type of alley access to property
#
#        Grvl	Gravel
#        Pave	Paved
#        NA 	No alley access
# Replace with NO for No alley access to use as new class

# %%
all_x_wo_missing['Alley'] = all_x['Alley'].fillna('NO')

# %% [markdown]
# ##### Fence
# Fence: Fence quality
#
#        GdPrv	Good Privacy
#        MnPrv	Minimum Privacy
#        GdWo	Good Wood
#        MnWw	Minimum Wood/Wire
#        NA	No Fence
# Replace with NO for No Fence to use as new class

# %%
all_x_wo_missing['Fence'] = all_x['Fence'].fillna('NO')

# %% [markdown]
# ##### FireplaceQu
# FireplaceQu: Fireplace quality
#
#        Ex	Excellent - Exceptional Masonry Fireplace
#        Gd	Good - Masonry Fireplace in main level
#        TA	Average - Prefabricated Fireplace in main living area or Masonry Fireplace in basement
#        Fa	Fair - Prefabricated Fireplace in basement
#        Po	Poor - Ben Franklin Stove
#        NA	No Fireplace
# Replace with NO for No Fireplace to use as new class

# %%
all_x_wo_missing['FireplaceQu'] = all_x['FireplaceQu'].fillna('NO')

# %% [markdown]
# ##### LotFrontage
# LotFrontage: Linear feet of street connected to property

# %% [markdown]
# Check correlation between LotFrontage and and other columns

# %%
plot_correlation(numerical, 'LotFrontage', 10)

# %% [markdown]
# Correlation between LotFrontage and  LotArea use LinearRegression for predicting the missing value.We can use LotArea because there is no missing value and there is a correlation

# %%
y = 'LotFrontage'
x = 'LotArea'
data = pd.DataFrame()
data[x]=all_x[x]
data[y]=all_x[y]
data  = data.dropna()
data = data.sort_values(by=[x])

from sklearn.linear_model import LinearRegression


y_vals = data[y]
x_vals = data.drop(y,  axis=1)

lr = LinearRegression()
model = lr.fit(x_vals,y_vals)

#predict = model.predict(all_x['LotArea'])
missing_columns = all_x[all_x['LotFrontage'].isnull()][['LotArea']]
values = model.predict(missing_columns).values[0]
all_x_wo_missing['LotFrontage'] = all_x['LotFrontage'].fillna(value=values)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-287-ebb0877af863> in <module>
#      18 #predict = model.predict(all_x['LotArea'])
#      19 missing_columns = all_x[all_x['LotFrontage'].isnull()][['LotArea']]
# ---> 20 values = model.predict(missing_columns).values[0]
#      21 all_x_wo_missing['LotFrontage'] = all_x['LotFrontage'].fillna(value=values)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %% [markdown]
# ##### GarageFinish

# %% [markdown]
# ##### GarageYrBlt

# %% [markdown]
# ##### GarageQual

# %% [markdown]
# ##### GarageCond

# %% [markdown]
# ##### GarageType

# %% [markdown]
# ##### BsmtExposure

# %% [markdown]
# ##### BsmtCond

# %% [markdown]
# ##### BsmtQual

# %% [markdown]
# ##### BsmtFinType2

# %% [markdown]
# ##### BsmtFinType1

# %% [markdown]
# ##### MasVnrType

# %% [markdown]
# ##### MasVnrArea

# %% [markdown]
# ##### MSZoning

# %% [markdown]
# ##### BsmtFullBath

# %% [markdown]
# ##### BsmtHalfBath

# %% [markdown]
# ##### Utilities

# %% [markdown]
# ##### Functional

# %% [markdown]
# ##### Exterior2nd

# %% [markdown]
# ##### Exterior1st

# %% [markdown]
# ##### SaleType

# %% [markdown]
# ##### BsmtFinSF1

# %% [markdown]
# ##### BsmtFinSF2

# %% [markdown]
# ##### BsmtUnfSF

# %% [markdown]
# ##### Electrical

# %% [markdown]
# ##### KitchenQual

# %% [markdown]
# ##### GarageCars

# %% [markdown]
# ##### GarageArea

# %% [markdown]
# ##### TotalBsmtSF
